# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import json,requests
import folium
from folium.plugins import MeasureControl
from folium.plugins import HeatMap
import os
from dotenv import load_dotenv

# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
client=MongoClient("mongodb://localhost:27017/")
db=client.companies

# %%
companies=db.companies.find()

# %%
datos= pd.DataFrame(companies)

# %%
datos.head()

# %%
datos["category_code"].value_counts()

# %%
query = db.companies.find({"$and":[
                               {"founded_year": {"$gte": 1990}},
                               {"number_of_employees": {"$gte": 7}},
                                {"total_money_raised":{"$regex":"M"}},
                               {"$or": [
                                   {"category_code": "design" } ,
                                   {"category_code": "biotech" } ,
                                   {"category_code":"games_video"},
                                   {"category_code":"web"},
                                   {"category_code": "software" } ,
                                   {"category_code": "education" } ,
                                   ]}
                               ],
                               },
                                {"_id": 0, "crunchbase_url": 0, "products": 0, "founded_month": 0, "founded_day": 0,
                                "acquisition": 0, "acquisitions": 0, "video_embeds": 0,
                                "screenshots": 0, "external_links": 0, "partners": 0,
                                "image": 0, "blog_feed_url": 0, "blog_url":0, "deadpooled_day":0,
                                "deadpooled_year":0, "deadpooled_month":0, "deadpooled_url":0, "ipo":0,
                                "permalink":0, "homepage_url":0, "tag_list":0, "email_addres": 0, "providerships": 0,
                                "milestones": 0, "twitter_username": 0, "updated_at": 0, "email_address":0, "investments":0,
                               }
                                    )

# %%
datos= pd.DataFrame(query)

# %%
datos.head()

# %%
datos.shape

# %%
datos.isnull().sum()

# %%
datos.drop(columns=["alias_list","created_at"],inplace=True)

# %%
datos["description"]=datos["description"].fillna(0)

# %%
datos=datos.replace(np.nan,0)

# %%
datos.isnull().sum()

# %%
datos.shape

# %%
datos.dropna(how="all",subset={"offices"},inplace=True)

# %%
latitude = db.companies.find({},{"offices.latitude":1})
longitude = db.companies.find({},{"offices.longitude":1})

# %%
def geopoint(x):
   for ele in x:
       longitude = ele["longitude"]
       latitude = ele["latitude"]
       return{"type": "Point", "coordinates": {"longitude":longitude,"latitude":latitude}}
    
datos["geo"] = datos["offices"].apply(geopoint)

# %%
datos["geo"].value_counts()

# %%
a=datos[datos["geo"].isnull()].index

# %%
datos.drop(a,axis=0,inplace=True)

# %%
datos["geo"].isnull().sum()

# %%
b=datos[datos["geo"]=={'type': 'Point', 'coordinates': {'longitude': None, 'latitude': None}}].index
datos.drop(b,axis=0,inplace=True)

# %%
datos["geo"].value_counts()

# %%
datos.to_json(r'./oficina.json', orient="records")

# %% [markdown]
# Ahora traigo la coleccion limpiada y con el geoindice creado

# %%
db = client.companies
consulta=db.indice.find()

# %%
cercania = pd.DataFrame(consulta)

# %%
cercania.head()

# %%
cercania.shape

# %%
cercania["offices"].value_counts()

# %%
ciudades=[e[0]["city"] for e in cercania["offices"]]

# %%
len(ciudades)

# %%
cercania["ciudades"]=ciudades

# %%
def gps (eg):
    cercania["longitude"]=[e["coordinates"]["longitude"] for e in cercania["geo"]]
    cercania["latitude"]=[e["coordinates"]["latitude"] for e in cercania["geo"]]
    return

# %%
cercania["geo"].apply(gps)

# %%
display(cercania)

# %%
def buscador (ciudad):
    a=cercania[cercania["ciudades"]==ciudad].index
    centrar=cercania.iloc[a,14:17]
    return centrar

# %%
b=buscador("New York")

# %% [markdown]
# Ahora busco la empresas que esten mas cerca del centro de Nueva York, lo cual devuelve que de toda mi coleccion ninguna esta a menos de 1km del centro.

# %%
coords = [-73.950566, 40.671678,]

cerca=db.indice.find({
   "geo": {
     "$near": {
       "$geometry": {
          "type": "Point" ,
          "coordinates": coords
       },
       "$maxDistance": 1000,
     }
   }
})

# %%
df_cerca=pd.DataFrame(cerca)

# %%
df_cerca.sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Enriquecer con API
# Uso la API de foursquare para enriquecer mi base de datos.
#
# 1) Starbucks cercanos

# %%
load_dotenv(dotenv_path="./input/.env")
client_secret=os.getenv("client_secret")

# %%
url = 'https://api.foursquare.com/v2/venues/explore'
params = dict(
 client_id='BK1LUEVPQKUICZTO2Y2ZX1XZLFLTPD0AJVMXXPOT04AQ1W5P',
 client_secret=client_secret,
 v='20180323',
 ll='40.7243,-74.0018',
 query='Starbucks',
)
resp = requests.get(url=url, params=params)
data_api = json.loads(resp.text)

# %%
display(data_api)
# Out:
# {'meta': {'code': 200, 'requestId': '5d88dcd3cc7d410037a1c8c1'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'suggestedRadius': 600,
#   'headerLocation': 'SoHo',
#   'headerFullLocation': 'SoHo, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'starbucks',
#   'totalResults': 51,
#   'suggestedBounds': {'ne': {'lat': 40.743224295893356, 'lng': -73.9899953035},
#    'sw': {'lat': 40.70884472813157, 'lng': -74.0166453665}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516409d5e4b0ec7be4b67ab4',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '370 Canal St',
#         'crossStreet': 'at Sheraton Tribeca',
#         'lat': 40.72083669737171,
#         'lng': -74.00436571600838,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72083669737171,
#           'lng': -74.00436571600838}],
#         'distance': 442,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['370 Canal St (at Sheraton Tribeca)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-516409d5e4b0ec7be4b67ab4-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57da31dacd10a259785fd379',
#        'name': 'Starbucks Reserve',
#        'contact': {},
#        'location': {'address': '10 Waverly Pl',
#         'crossStreet': 'at Mercer St',
#         'lat': 40.72994333023035,
#         'lng': -73.9939131949986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72994333023035,
#           'lng': -73.9939131949986}],
#         'distance': 915,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['10 Waverly Pl (at Mercer St)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-57da31dacd10a259785fd379-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a663fe9f964a5204ac81fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '482 West Broadway',
#         'crossStreet': 'at W Houston St',
#         'lat': 40.72689,
#         'lng': -74.00026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72689,
#           'lng': -74.00026}],
#         'distance': 316,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['482 West Broadway (at W Houston St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a663fe9f964a5204ac81fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5385a684498e2379f61a25a1',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '32 Avenue of the Americas',
#         'crossStreet': 'at Walker St',
#         'lat': 40.719852,
#         'lng': -74.00495,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.719852,
#           'lng': -74.00495}],
#         'distance': 561,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['32 Avenue of the Americas (at Walker St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5385a684498e2379f61a25a1-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e644c6f964a5202f641fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '72 Spring St',
#         'crossStreet': 'at Crosby St',
#         'lat': 40.722584953691005,
#         'lng': -73.9980228047693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.722584953691005,
#           'lng': -73.9980228047693}],
#         'distance': 371,
#         'postalCode': '10012',
#         'cc': 'US',
#         'neighborhood': 'SoHo',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['72 Spring St (at Crosby St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-49e644c6f964a5202f641fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7a3d3f775b9ed4d3854ca6',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '180 West Broadway',
#         'crossStreet': 'at Leonard St',
#         'lat': 40.71823,
#         'lng': -74.00732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71823,
#           'lng': -74.00732}],
#         'distance': 820,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['180 West Broadway (at Leonard St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4e7a3d3f775b9ed4d3854ca6-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d82a5c498ebdc6681b0e13',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '239 Bleecker St',
#         'lat': 40.730647126953016,
#         'lng': -74.0026079003726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.730647126953016,
#           'lng': -74.0026079003726}],
#         'distance': 709,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['239 Bleecker St',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-53d82a5c498ebdc6681b0e13-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9320d2f964a520e31e20e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '150 Varick Street',
#         'crossStreet': 'at Spring St',
#         'lat': 40.72572004349832,
#         'lng': -74.00568558837828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72572004349832,
#           'lng': -74.00568558837828}],
#         'distance': 363,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['150 Varick Street (at Spring St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a9320d2f964a520e31e20e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a6dea38f964a52052d31fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '405 Broadway',
#         'crossStreet': 'btwn Walker & Lispenard St',
#         'lat': 40.71880196675863,
#         'lng': -74.00243121466805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71880196675863,
#           'lng': -74.00243121466805}],
#         'distance': 614,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['405 Broadway (btwn Walker & Lispenard St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 2,
#         'summary': '2 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 2,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a6dea38f964a52052d31fe3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada106af964a520ed1d21e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '72 Grove St',
#         'crossStreet': 'at 7th Ave S',
#         'lat': 40.73318,
#         'lng': -74.00293,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73318,
#           'lng': -74.00293}],
#         'distance': 993,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['72 Grove St (at 7th Ave S)',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ada106af964a520ed1d21e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a809c7df964a520b2f51fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '665 Broadway',
#         'crossStreet': 'at Bond St',
#         'lat': 40.727192,
#         'lng': -73.99546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.727192,
#           'lng': -73.99546}],
#         'distance': 624,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['665 Broadway (at Bond St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a809c7df964a520b2f51fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '46712cd5f964a520c8471fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '111 Worth St',
#         'crossStreet': 'at Lafayette St',
#         'lat': 40.71571383553879,
#         'lng': -74.0031541656601,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71571383553879,
#           'lng': -74.0031541656601}],
#         'distance': 962,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['111 Worth St (at Lafayette St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-46712cd5f964a520c8471fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a19b507f964a520347a1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '241 Canal Street',
#         'crossStreet': 'at Centre St',
#         'lat': 40.71833,
#         'lng': -74.000015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71833,
#           'lng': -74.000015}],
#         'distance': 681,
#         'postalCode': '10013',
#         'cc': 'US',
#         'neighborhood': 'Chinatown',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['241 Canal Street (at Centre St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a19b507f964a520347a1fe3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aabc152f964a520f15920e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '120 Church Street',
#         'crossStreet': 'at Murray St',
#         'lat': 40.713838516500275,
#         'lng': -74.00902572737122,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.713838516500275,
#           'lng': -74.00902572737122}],
#         'distance': 1314,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['120 Church Street (at Murray St)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4aabc152f964a520f15920e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af4448cf964a520fbf021e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '378 6th Avenue',
#         'crossStreet': 'at Waverly Pl',
#         'lat': 40.733033,
#         'lng': -73.999677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.733033,
#           'lng': -73.999677}],
#         'distance': 988,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['378 6th Avenue (at Waverly Pl)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4af4448cf964a520fbf021e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce41f161594236ac316fb49',
#        'name': 'Starbucks Reserve',
#        'contact': {},
#        'location': {'address': '250 Vesey St',
#         'crossStreet': '2nd Fl',
#         'lat': 40.71417,
#         'lng': -74.015434,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71417,
#           'lng': -74.015434}],
#         'distance': 1610,
#         'postalCode': '10281',
#         'cc': 'US',
#         'neighborhood': 'Battery Park City',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['250 Vesey St (2nd Fl)',
#          'New York, NY 10281',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 3,
#         'summary': '3 people are here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 3,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ce41f161594236ac316fb49-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae70d4512f0a9002c41d236',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '157 Lafayette St',
#         'lat': 40.71983316831819,
#         'lng': -73.99925263833434,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71983316831819,
#           'lng': -73.99925263833434}],
#         'distance': 541,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['157 Lafayette St',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '1229962',
#         'url': 'https://www.seamless.com/menu/starbucks-157-lafayette-st-new-york/1229962?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1229962',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5ae70d4512f0a9002c41d236-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6c3b0df964a520d12a2ce3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '97 Warren St',
#         'crossStreet': 'at Greenwich St',
#         'lat': 40.71559728431799,
#         'lng': -74.01170644013654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71559728431799,
#           'lng': -74.01170644013654}],
#         'distance': 1279,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['97 Warren St (at Greenwich St)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b6c3b0df964a520d12a2ce3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad76597f964a5200e0a21e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '233 Broadway',
#         'crossStreet': 'at Barclay St',
#         'lat': 40.71220388,
#         'lng': -74.00805192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71220388,
#           'lng': -74.00805192}],
#         'distance': 1446,
#         'postalCode': '10279',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['233 Broadway (at Barclay St)',
#          'New York, NY 10279',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ad76597f964a5200e0a21e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aea76b3f964a520abbb21e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '291 Broadway',
#         'crossStreet': 'at Reade St',
#         'lat': 40.714855,
#         'lng': -74.005936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714855,
#           'lng': -74.005936}],
#         'distance': 1107,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['291 Broadway (at Reade St)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4aea76b3f964a520abbb21e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49c64908f964a52030571fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '93 Greenwich Ave',
#         'crossStreet': 'at Bank St',
#         'lat': 40.73725,
#         'lng': -74.00172,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73725,
#           'lng': -74.00172}],
#         'distance': 1441,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['93 Greenwich Ave (at Bank St)',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-49c64908f964a52030571fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a718a5af964a52041d91fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '125 Chambers St',
#         'crossStreet': 'at W Broadway',
#         'lat': 40.715534,
#         'lng': -74.00903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715534,
#           'lng': -74.00903}],
#         'distance': 1150,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['125 Chambers St (at W Broadway)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a718a5af964a52041d91fe3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49da74aef964a5208b5e1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '13-25 Astor Pl',
#         'crossStreet': 'at Lafayette St',
#         'lat': 40.72990798225845,
#         'lng': -73.99140743961189,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72990798225845,
#           'lng': -73.99140743961189}],
#         'distance': 1076,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['13-25 Astor Pl (at Lafayette St)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-49da74aef964a5208b5e1fe3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3abbc9b2289521d209f70c',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '518 Hudson Street',
#         'lat': 40.73371260231791,
#         'lng': -74.00627519979301,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73371260231791,
#           'lng': -74.00627519979301}],
#         'distance': 1113,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['518 Hudson Street',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c3abbc9b2289521d209f70c-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c13bf838afbe0002de55061',
#        'name': 'Starbucks Reserve Roastery',
#        'contact': {},
#        'location': {'address': '61 9th Ave',
#         'crossStreet': 'at W 15th St',
#         'lat': 40.74166158826782,
#         'lng': -74.00507982765883,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74166158826782,
#           'lng': -74.00507982765883}],
#         'distance': 1952,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['61 9th Ave (at W 15th St)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5c13bf838afbe0002de55061-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bd33b9e46e1b6002c620f2d',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '4 World Trade Ctr',
#         'crossStreet': 'Wall St.',
#         'lat': 40.7104074357571,
#         'lng': -74.01170062726673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7104074357571,
#           'lng': -74.01170062726673}],
#         'distance': 1757,
#         'postalCode': '10007',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4 World Trade Ctr (Wall St.)',
#          'New York, NY 10007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5bd33b9e46e1b6002c620f2d-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49b15042f964a520d4521fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '345 Hudson St',
#         'crossStreet': 'btwn Charlton & King St',
#         'lat': 40.72758485,
#         'lng': -74.00740732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72758485,
#           'lng': -74.00740732}],
#         'distance': 597,
#         'postalCode': '10014',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['345 Hudson St (btwn Charlton & King St)',
#          'New York, NY 10014',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-49b15042f964a520d4521fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5601a351498e93b8e86a4747',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '25 Union Sq W',
#         'crossStreet': 'btwn W 15th & W 16th St',
#         'lat': 40.73628194,
#         'lng': -73.99120667,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73628194,
#           'lng': -73.99120667}],
#         'distance': 1605,
#         'postalCode': '10003',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['25 Union Sq W (btwn W 15th & W 16th St)',
#          'New York, NY 10003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5601a351498e93b8e86a4747-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a84eb0af964a520e1fd1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '38 Park Row',
#         'crossStreet': 'at Beekman St',
#         'lat': 40.71159756,
#         'lng': -74.00672626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71159756,
#           'lng': -74.00672626}],
#         'distance': 1473,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['38 Park Row (at Beekman St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a84eb0af964a520e1fd1fe3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a1c91b1f964a520527b1fe3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '510 Sixth Ave',
#         'crossStreet': 'at W 14th St',
#         'lat': 40.73698,
#         'lng': -73.9964,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.73698,
#           'lng': -73.9964}],
#         'distance': 1483,
#         'postalCode': '10011',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['510 Sixth Ave (at W 14th St)',
#          'New York, NY 10011',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4a1c91b1f964a520527b1fe3-29'}]}]}}

# %%
def cafe(lugar):
  nombre=[]
  latitud=[]
  longi=[]
  for e in data_api['response']['groups'][0]['items']:
      nombre.append(e['venue']['name'])
      latitud.append(e['venue']['location']['lat'])
      longi.append(e['venue']['location']['lng'])
  lugar = {"name":nombre, "latitude":latitud, "longitude":longi}
  return pd.DataFrame(lugar)
cafe = cafe(data_api)
cafe.head()

# %%
mapa= folium.Map(location=[40.722655, -73.998730], width=750, height=500, zoom_start=15)

# %%
for index, row in cafe.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                        radius=9,
                        popup="City: {}, latitude {}, longitude {}".format(row['name'], row['latitude'], row['longitude']),
                        icon=folium.Icon(icon_color='green',icon='cloud')
                       ).add_to(mapa)
    folium.Marker([40.722655,-73.998730],
                        radius=2,
                        icon=folium.Icon(icon='home'),
                       ).add_to(mapa)
    folium.Circle(location=[40.722655, -73.998730],
                    radius=500
                   ).add_to(mapa)
mapa.add_child(MeasureControl())

# %% [markdown]
# 2) Restaruantes veganos cercanos

# %%
url = 'https://api.foursquare.com/v2/venues/explore'
params = dict(
 client_id='BK1LUEVPQKUICZTO2Y2ZX1XZLFLTPD0AJVMXXPOT04AQ1W5P',
 client_secret=client_secret,
 v='20180323',
 ll='40.7243,-74.0018',
 query='4bf58dd8d48988d1d3941735',
)
resp = requests.get(url=url, params=params)
data_api2 = json.loads(resp.text)

# %%
display(data_api2)

# %%
def vegano(lugar):
  nombre=[]
  latitud=[]
  longi=[]
  for e in data_api2['response']['groups'][0]['items']:
      nombre.append(e['venue']['name'])
      latitud.append(e['venue']['location']['lat'])
      longi.append(e['venue']['location']['lng'])
  lugar = {"name":nombre, "latitude":latitud, "longitude":longi}
  return pd.DataFrame(lugar)
vegano = vegano(data_api2)
vegano.head()

# %%
for index, row in vegano.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                        radius=9,
                        popup="City: {}, latitude {}, longitude {}".format(row['name'], row['latitude'], row['longitude']),
                  icon=folium.Icon(icon_color='white',icon='info-sign')
                       ).add_to(mapa)

# %%
mapa
